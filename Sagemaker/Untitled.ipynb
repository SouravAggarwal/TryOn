# %%
import requests

kaggle_models = "https://www.kaggle.com/api/v1/datasets/download/souravaggarwal9/virtualwearmodel"
response = requests.get(kaggle_models, stream=True)

with open("dataset.zip", "wb") as file:
    for chunk in response.iter_content(chunk_size=1024):
        file.write(chunk)

print("Download complete!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import requests
#       3 kaggle_models = "https://www.kaggle.com/api/v1/datasets/download/souravaggarwal9/virtualwearmodel"
# ----> 4 requests.get(kaggle_models)
#
# File /Volumes/Personal/Projects/TryOn/Sagemaker/venv/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Volumes/Personal/Projects/TryOn/Sagemaker/venv/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
# ...

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi

# Generate API token from https://www.kaggle.com/settings
os.environ["KAGGLE_USERNAME"] = "souravaggarwal9"
os.environ["KAGGLE_KEY"] = "ee841921803807c7b3cdd523125564ba"

# Initialize Kaggle API
api = KaggleApi()
api.authenticate()

# List files in a dataset
dataset = "souravaggarwal9/virtualwearmodel"  # Replace with your dataset name
files = api.dataset_list_files(dataset).files

# Print file names
for f in files:
    print(f.name)
# Out:
# IDM-VTON/README.md
# IDM-VTON/assets/teaser.png
# IDM-VTON/assets/teaser2.png
# IDM-VTON/densepose/model_final_162be9.pkl
# IDM-VTON/humanparsing/parsing_atr.onnx
# IDM-VTON/humanparsing/parsing_lip.onnx
# IDM-VTON/image_encoder/config.json
# IDM-VTON/image_encoder/model.safetensors
# IDM-VTON/model_index.json
# IDM-VTON/openpose/ckpts/body_pose_model.pth
# IDM-VTON/scheduler/scheduler_config.json
# IDM-VTON/text_encoder/config.json
# IDM-VTON/text_encoder/model.safetensors
# IDM-VTON/text_encoder_2/config.json
# IDM-VTON/text_encoder_2/model.safetensors
# IDM-VTON/tokenizer/merges.txt
# IDM-VTON/tokenizer/special_tokens_map.json
# IDM-VTON/tokenizer/tokenizer_config.json
# IDM-VTON/tokenizer/vocab.json
# IDM-VTON/tokenizer_2/merges.txt

# %%
import kaggle

dataset = "souravaggarwal9/virtualwearmodel"
files = kaggle.api.dataset_list_files(dataset).files

# Print all file paths in the dataset
for f in files:
    print(f.name)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import kaggle
#       3 dataset = "souravaggarwal9/virtualwearmodel"
#       4 files = kaggle.api.dataset_list_files(dataset).files
#
# File /Volumes/Personal/Projects/TryOn/Sagemaker/venv/lib/python3.11/site-packages/kaggle/__init__.py:7
#       4 from kaggle.api_client import ApiClient
#       6 api = KaggleApi(ApiClient())
# ----> 7 api.authenticate()
#
# File /Volumes/Personal/Projects/TryOn/Sagemaker/venv/lib/python3.11/site-packages/kaggle/api/kaggle_api_extended.py:407, in KaggleApi.authenticate(self)
#     405         return
#     406     else:
# --> 407         raise IOError('Could not find {}. Make sure it\'s located in'
#     408                       ' {}. Or use the environment method. See setup'
#     409                       ' instructions at'
# ...
